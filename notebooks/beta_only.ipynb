# %% [markdown]
# # Stress test, beta only

# %%
import sys
import pandas as pd
import numpy as np
import random
import tensorflow as tf
import plotly.express as px
import plotly.graph_objects as go
import os
os.environ["PYTHONHASHSEED"] = "42"
os.environ["TF_DETERMINISTIC_OPS"] = "1"
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from pathlib import Path

project_root = Path.cwd()
while project_root != project_root.parent and not (project_root / "src").exists():
    project_root = project_root.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.simulation.dgp0 import Tier0Config, simulate_panel
from src.simulation.validation import plot_market_plotly
from src.data.feature_eng import feature_eng_syn
from src.model.autoencoder import PriceAutoencoder


#set seed
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
df_beta = pd.read_parquet("../data/processed_syn/synth_dgp0_beta_only_L18.parquet")
df_beta.head()
# Out:
#    market_id  window_start  window_end  window_length   Price 1   Price 2  \
# 0          0             0          17             18  0.066714  0.063165
# 1          0             1          18             18  0.063165  0.056164
# 2          0             2          19             18  0.056164  0.046739
# 3          0             3          20             18  0.046739  0.051370
# 4          0             4          21             18  0.051370  0.051328
#
#     Price 3   Price 4   Price 5   Price 6  ...  Price 14  Price 15  Price 16  \
# 0  0.056164  0.046739  0.051370  0.051328  ...  0.001583 -0.006167 -0.012466
# 1  0.046739  0.051370  0.051328  0.055144  ... -0.006167 -0.012466 -0.024368
# 2  0.051370  0.051328  0.055144  0.032062  ... -0.012466 -0.024368 -0.020971
# 3  0.051328  0.055144  0.032062  0.056263  ... -0.024368 -0.020971 -0.078333
# 4  0.055144  0.032062  0.056263  0.062923  ... -0.020971 -0.078333 -0.095205
#
#    Price 17  Price 18   share_C   share_T  share_K  state_mode  is_pure_80
# 0 -0.024368 -0.020971  0.111111  0.888889      0.0           1         1.0
# 1 -0.020971 -0.078333  0.166667  0.833333      0.0           1         1.0
# 2 -0.078333 -0.095205  0.222222  0.777778      0.0           1         0.0
# 3 -0.095205 -0.105137  0.277778  0.722222      0.0           1         0.0
# 4 -0.105137 -0.100656  0.333333  0.666667      0.0           1         0.0
#
# [5 rows x 27 columns]

# %%
feature_df = feature_eng_syn(df_beta)
feature_df.head()
# Out:
#    market_id  window_start  window_end  window_length   Price 1   Price 2  \
# 0          0             0          17             18  0.066714  0.063165
# 1          0             1          18             18  0.063165  0.056164
# 2          0             2          19             18  0.056164  0.046739
# 3          0             3          20             18  0.046739  0.051370
# 4          0             4          21             18  0.051370  0.051328
#
#     Price 3   Price 4   Price 5   Price 6  ...  CoV_change  \
# 0  0.056164  0.046739  0.051370  0.051328  ...    2.414924
# 1  0.046739  0.051370  0.051328  0.055144  ...    2.099165
# 2  0.051370  0.051328  0.055144  0.032062  ...    1.974640
# 3  0.051328  0.055144  0.032062  0.056263  ...    1.968199
# 4  0.055144  0.032062  0.056263  0.062923  ...    1.965507
#
#    zero_change_fraction      AR_1      AR_2  kurtosis_change  max_abs_ret  \
# 0              0.058824 -0.127866  0.033985         1.999154     0.035017
# 1              0.058824 -0.210967  0.113727         2.902990     0.057362
# 2              0.058824 -0.069755  0.100084         2.563596     0.057362
# 3              0.058824 -0.067532  0.075652         2.552966     0.057362
# 4              0.058824 -0.095961  0.014479         2.558677     0.057362
#
#     pos_vol   neg_vol  level_vol  price_range
# 0  0.008844  0.009518   0.031747     0.091082
# 1  0.008844  0.016134   0.039876     0.141498
# 2  0.008844  0.015920   0.047528     0.158129
# 3  0.008844  0.015901   0.054151     0.168061
# 4  0.008861  0.015901   0.058668     0.168061
#
# [5 rows x 39 columns]

# %% [markdown]
# ## Training AE

# %%
FEATURES_5 = [
    "volatility", "zero_change_fraction","max_abs_ret",
    "AR_1","price_range"]

X = feature_df[FEATURES_5].to_numpy().astype(np.float32)

# Scale
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X).astype(np.float32)

#train test split
X_train, X_val = train_test_split(X_scaled, test_size=0.2, random_state=42)

# %%
ae = PriceAutoencoder(input_dim=5, latent_dim=2, hidden_dims=(16,8), latent_activation=None)
ae.compile(optimizer=tf.keras.optimizers.Adam(1e-3), loss="mse")

history = ae.fit(
    X_train, X_train,
    validation_data=(X_val, X_val),
    epochs=200,
    batch_size=256,
    callbacks=[tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)],
    verbose=1
)
# Out:
# Epoch 1/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8315 - val_loss: 0.5612
# Epoch 2/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3003 - val_loss: 0.2023
# Epoch 3/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1827 - val_loss: 0.1639
# Epoch 4/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1580 - val_loss: 0.1483
# Epoch 5/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1472 - val_loss: 0.1411
# Epoch 6/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1410 - val_loss: 0.1363
# Epoch 7/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1366 - val_loss: 0.1330
# Epoch 8/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1335 - val_loss: 0.1304
# Epoch 9/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1310 - val_loss: 0.1285
# Epoch 10/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1291 - val_loss: 0.1271
# Epoch 11/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1275 - val_loss: 0.1257
# Epoch 12/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1261 - val_loss: 0.1245
# Epoch 13/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 0.1248 - val_loss: 0.1234
# Epoch 14/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1237 - val_loss: 0.1223
# Epoch 15/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1226 - val_loss: 0.1212
# Epoch 16/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1216 - val_loss: 0.1204
# Epoch 17/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1208 - val_loss: 0.1197
# Epoch 18/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1201 - val_loss: 0.1191
# Epoch 19/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1195 - val_loss: 0.1185
# Epoch 20/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1189 - val_loss: 0.1179
# Epoch 21/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1183 - val_loss: 0.1174
# Epoch 22/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1178 - val_loss: 0.1169
# Epoch 23/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1173 - val_loss: 0.1165
# Epoch 24/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1168 - val_loss: 0.1161
# Epoch 25/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1164 - val_loss: 0.1157
# Epoch 26/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1159 - val_loss: 0.1154
# Epoch 27/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1155 - val_loss: 0.1151
# Epoch 28/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1151 - val_loss: 0.1147
# Epoch 29/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1147 - val_loss: 0.1144
# Epoch 30/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1143 - val_loss: 0.1141
# Epoch 31/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1140 - val_loss: 0.1138
# Epoch 32/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1137 - val_loss: 0.1135
# Epoch 33/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1134 - val_loss: 0.1132
# Epoch 34/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1131 - val_loss: 0.1130
# Epoch 35/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1128 - val_loss: 0.1127
# Epoch 36/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1125 - val_loss: 0.1125
# Epoch 37/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1123 - val_loss: 0.1122
# Epoch 38/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1120 - val_loss: 0.1120
# Epoch 39/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1118 - val_loss: 0.1118
# Epoch 40/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1115 - val_loss: 0.1116
# Epoch 41/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1113 - val_loss: 0.1114
# Epoch 42/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1111 - val_loss: 0.1112
# Epoch 43/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1109 - val_loss: 0.1110
# Epoch 44/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1107 - val_loss: 0.1108
# Epoch 45/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1105 - val_loss: 0.1107
# Epoch 46/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1103 - val_loss: 0.1104
# Epoch 47/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1101 - val_loss: 0.1102
# Epoch 48/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1099 - val_loss: 0.1101
# Epoch 49/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1097 - val_loss: 0.1099
# Epoch 50/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1095 - val_loss: 0.1098
# Epoch 51/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1093 - val_loss: 0.1096
# Epoch 52/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1092 - val_loss: 0.1094
# Epoch 53/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1090 - val_loss: 0.1093
# Epoch 54/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1088 - val_loss: 0.1091
# Epoch 55/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1086 - val_loss: 0.1089
# Epoch 56/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1084 - val_loss: 0.1088
# Epoch 57/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1082 - val_loss: 0.1086
# Epoch 58/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1081 - val_loss: 0.1085
# Epoch 59/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1079 - val_loss: 0.1083
# Epoch 60/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1077 - val_loss: 0.1081
# Epoch 61/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1075 - val_loss: 0.1079
# Epoch 62/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1074 - val_loss: 0.1077
# Epoch 63/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1072 - val_loss: 0.1075
# Epoch 64/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1070 - val_loss: 0.1073
# Epoch 65/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1068 - val_loss: 0.1071
# Epoch 66/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1066 - val_loss: 0.1069
# Epoch 67/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1065 - val_loss: 0.1068
# Epoch 68/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1063 - val_loss: 0.1067
# Epoch 69/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1063 - val_loss: 0.1063
# Epoch 70/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1060 - val_loss: 0.1062
# Epoch 71/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1058 - val_loss: 0.1061
# Epoch 72/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1057 - val_loss: 0.1059
# Epoch 73/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1055 - val_loss: 0.1058
# Epoch 74/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1054 - val_loss: 0.1056
# Epoch 75/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1052 - val_loss: 0.1054
# Epoch 76/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1051 - val_loss: 0.1053
# Epoch 77/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1050 - val_loss: 0.1051
# Epoch 78/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1048 - val_loss: 0.1050
# Epoch 79/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1047 - val_loss: 0.1048
# Epoch 80/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1046 - val_loss: 0.1047
# Epoch 81/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1045 - val_loss: 0.1046
# Epoch 82/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1044 - val_loss: 0.1044
# Epoch 83/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1043 - val_loss: 0.1042
# Epoch 84/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1042 - val_loss: 0.1041
# Epoch 85/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1041 - val_loss: 0.1040
# Epoch 86/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1040 - val_loss: 0.1039
# Epoch 87/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1039 - val_loss: 0.1037
# Epoch 88/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1038 - val_loss: 0.1037
# Epoch 89/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1037 - val_loss: 0.1036
# Epoch 90/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1036 - val_loss: 0.1034
# Epoch 91/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1035 - val_loss: 0.1033
# Epoch 92/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1034 - val_loss: 0.1034
# Epoch 93/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1034 - val_loss: 0.1030
# Epoch 94/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1032 - val_loss: 0.1030
# Epoch 95/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1032 - val_loss: 0.1029
# Epoch 96/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1031 - val_loss: 0.1030
# Epoch 97/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1031 - val_loss: 0.1028
# Epoch 98/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1029 - val_loss: 0.1028
# Epoch 99/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1029 - val_loss: 0.1029
# Epoch 100/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1028 - val_loss: 0.1026
# Epoch 101/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1028 - val_loss: 0.1026
# Epoch 102/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1027 - val_loss: 0.1025
# Epoch 103/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1027 - val_loss: 0.1024
# Epoch 104/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1027 - val_loss: 0.1025
# Epoch 105/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1027 - val_loss: 0.1023
# Epoch 106/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1025 - val_loss: 0.1024
# Epoch 107/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1024 - val_loss: 0.1023
# Epoch 108/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1026 - val_loss: 0.1019
# Epoch 109/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1023 - val_loss: 0.1019
# Epoch 110/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1022 - val_loss: 0.1018
# Epoch 111/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1022 - val_loss: 0.1020
# Epoch 112/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1021 - val_loss: 0.1021
# Epoch 113/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1020 - val_loss: 0.1020
# Epoch 114/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1020 - val_loss: 0.1020
# Epoch 115/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1019 - val_loss: 0.1019
# Epoch 116/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1019 - val_loss: 0.1019
# Epoch 117/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - val_loss: 0.1017
# Epoch 118/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1017 - val_loss: 0.1017
# Epoch 119/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1016 - val_loss: 0.1017
# Epoch 120/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1015 - val_loss: 0.1016
# Epoch 121/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1015 - val_loss: 0.1016
# Epoch 122/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1015 - val_loss: 0.1015
# Epoch 123/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1013 - val_loss: 0.1014
# Epoch 124/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1012 - val_loss: 0.1014
# Epoch 125/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1011 - val_loss: 0.1012
# Epoch 126/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1011 - val_loss: 0.1012
# Epoch 127/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1010 - val_loss: 0.1011
# Epoch 128/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1009 - val_loss: 0.1009
# Epoch 129/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1007 - val_loss: 0.1007
# Epoch 130/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1006 - val_loss: 0.1006
# Epoch 131/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1005 - val_loss: 0.1005
# Epoch 132/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1003 - val_loss: 0.1004
# Epoch 133/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1003 - val_loss: 0.1001
# Epoch 134/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1001 - val_loss: 0.1000
# Epoch 135/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1000 - val_loss: 0.0997
# Epoch 136/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0998 - val_loss: 0.0996
# Epoch 137/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0996 - val_loss: 0.0995
# Epoch 138/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0993 - val_loss: 0.0993
# Epoch 139/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0991 - val_loss: 0.0990
# Epoch 140/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0990 - val_loss: 0.0986
# Epoch 141/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0989 - val_loss: 0.0988
# Epoch 142/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0989 - val_loss: 0.0983
# Epoch 143/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0986 - val_loss: 0.0981
# Epoch 144/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0982 - val_loss: 0.0979
# Epoch 145/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0980 - val_loss: 0.0972
# Epoch 146/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0978 - val_loss: 0.0971
# Epoch 147/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0974 - val_loss: 0.0970
# Epoch 148/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0971 - val_loss: 0.0968
# Epoch 149/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0970 - val_loss: 0.0962
# Epoch 150/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0967 - val_loss: 0.0964
# Epoch 151/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0964 - val_loss: 0.0958
# Epoch 152/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0962 - val_loss: 0.0958
# Epoch 153/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0959 - val_loss: 0.0955
# Epoch 154/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0957 - val_loss: 0.0955
# Epoch 155/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0955 - val_loss: 0.0950
# Epoch 156/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0957 - val_loss: 0.0957
# Epoch 157/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0955 - val_loss: 0.0955
# Epoch 158/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0949 - val_loss: 0.0950
# Epoch 159/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0949 - val_loss: 0.0949
# Epoch 160/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0947 - val_loss: 0.0946
# Epoch 161/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0947 - val_loss: 0.0947
# Epoch 162/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0944 - val_loss: 0.0940
# Epoch 163/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0938 - val_loss: 0.0938
# Epoch 164/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0937 - val_loss: 0.0936
# Epoch 165/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0935 - val_loss: 0.0934
# Epoch 166/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0934 - val_loss: 0.0933
# Epoch 167/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0933 - val_loss: 0.0932
# Epoch 168/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0932 - val_loss: 0.0931
# Epoch 169/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0931 - val_loss: 0.0930
# Epoch 170/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0930 - val_loss: 0.0930
# Epoch 171/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0929 - val_loss: 0.0930
# Epoch 172/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0928 - val_loss: 0.0929
# Epoch 173/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0928 - val_loss: 0.0928
# Epoch 174/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0927 - val_loss: 0.0930
# Epoch 175/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0926 - val_loss: 0.0930
# Epoch 176/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0925 - val_loss: 0.0929
# Epoch 177/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0925 - val_loss: 0.0928
# Epoch 178/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0924 - val_loss: 0.0927
# Epoch 179/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0925 - val_loss: 0.0927
# Epoch 180/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0923 - val_loss: 0.0926
# Epoch 181/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0923 - val_loss: 0.0925
# Epoch 182/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0922 - val_loss: 0.0926
# Epoch 183/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0922 - val_loss: 0.0925
# Epoch 184/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0922 - val_loss: 0.0923
# Epoch 185/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0921 - val_loss: 0.0924
# Epoch 186/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0920 - val_loss: 0.0923
# Epoch 187/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0919 - val_loss: 0.0923
# Epoch 188/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0920 - val_loss: 0.0923
# Epoch 189/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0920 - val_loss: 0.0918
# Epoch 190/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0918 - val_loss: 0.0922
# Epoch 191/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0918 - val_loss: 0.0920
# Epoch 192/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0917 - val_loss: 0.0921
# Epoch 193/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0916 - val_loss: 0.0921
# Epoch 194/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0916 - val_loss: 0.0919
# Epoch 195/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0915 - val_loss: 0.0919
# Epoch 196/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0914 - val_loss: 0.0919
# Epoch 197/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0915 - val_loss: 0.0918
# Epoch 198/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0914 - val_loss: 0.0918
# Epoch 199/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0913 - val_loss: 0.0917
# Epoch 200/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0912 - val_loss: 0.0915

# %% [markdown]
# ## Checking Embedding

# %%
Z = ae.encoder(X_scaled).numpy()

validation_df = feature_df.copy()

validation_df["z1"] = Z[:, 0]
validation_df["z2"] = Z[:, 1]

# %%
#plotting embedding
# Focus on pure windows only for clarity
pure = validation_df[validation_df["is_pure_80"] == 1].copy()

# Map state labels for readability
state_map = {0: "Competitive", 1: "Tacit", 2: "Cartel"}
pure["state_label"] = pure["state_mode"].map(state_map)

fig = px.scatter(
    pure,
    x="z1",
    y="z2",
    color="state_label",
    color_discrete_map={
        "Competitive": "green",
        "Tacit": "orange",
        "Cartel": "red",
    },
    title="Latent Space (Pure Windows Only) Beta Only",
    opacity=0.6
)

fig.update_layout(template="plotly_white")
fig.show()

# %% [markdown]
# ## Calulating Centriods

# %%
Z_pure = pure[["z1","z2"]].to_numpy()


#cacluating centroids
mu_C = pure[pure["state_mode"] == 0][["z1","z2"]].mean().to_numpy()
mu_K = pure[pure["state_mode"] == 2][["z1","z2"]].mean().to_numpy()
mu_T = pure[pure["state_mode"] == 1][["z1","z2"]].mean().to_numpy()

#calculating competition direction and scalling 
v = mu_K - mu_C
v = v / np.linalg.norm(v)

# %%
#projecting each coordinate on competitoin axis
Z_all = validation_df[["z1","z2"]].to_numpy()
validation_df["conduct_score"] = Z_all @ v
validation_df["conduct_score_centred"] = (Z_all - mu_C) @ v

# %%
validation_df.groupby("state_mode")["conduct_score"].mean()
# Out:
# state_mode
# 0   -0.875820
# 1   -0.183474
# 2    0.628294
# Name: conduct_score, dtype: float32

# %%
validation_df.groupby("state_mode")["conduct_score"].describe()
# Out:
#               count      mean       std       min       25%       50%  \
# state_mode
# 0            9572.0 -0.875820  1.762113 -8.674465 -1.748693 -0.829645
# 1            9494.0 -0.183474  1.937697 -7.071560 -0.943801 -0.527588
# 2           13534.0  0.628294  1.875236 -7.129918 -0.523122 -0.050868
#
#                  75%        max
# state_mode
# 0          -0.357198   7.571280
# 1           0.162733  11.689965
# 2           0.797011   9.853680

# %% [markdown]
# ## Understanding Classification

# %%
state_map = {0: "Competitive", 1: "Tacit", 2: "Cartel"}

pure["state_label"] = pure["state_mode"].map(state_map)
validation_df["state_label"] = validation_df["state_mode"].map(state_map)

# %%
fig = px.scatter(
    pure,
    x="z1",
    y="z2",
    color="state_label",
    opacity=0,
    title="Latent Space (Beta only) with Centroids and Conduct Axis",
    template="plotly_white"
)

# Add centroid markers
centroids = np.vstack([mu_C, mu_T, mu_K])
centroid_labels = ["Competitive centroid", "Tacit centroid", "Cartel centroid"]

fig.add_trace(go.Scatter(
    x=centroids[:,0],
    y=centroids[:,1],
    mode="markers+text",
    text=centroid_labels,
    textposition="top center",
    marker=dict(size=14, symbol="x"),
    name="Centroids"
))

# Add arrow from mu_C to mu_K
fig.add_trace(go.Scatter(
    x=[mu_C[0], mu_K[0]],
    y=[mu_C[1], mu_K[1]],
    mode="lines",
    line=dict(width=4, dash="dash"),
    name="Conduct axis (C → K)"
))

# Optional: annotate arrow direction
fig.add_annotation(
    x=mu_K[0], y=mu_K[1],
    ax=mu_C[0], ay=mu_C[1],
    xref="x", yref="y", axref="x", ayref="y",
    showarrow=True, arrowhead=3, arrowsize=1.2, arrowwidth=2,
    text="C→K"
)

fig.show()

# %%
fig = px.histogram(
    validation_df,
    x="conduct_score_centred",
    color="state_label",
    nbins=60,
    opacity=0.5,
    barmode="overlay",
    title="Centered Conduct Score Distribution by Regime (All Windows) Beta only",
    template="plotly_white"
)
fig.show()
