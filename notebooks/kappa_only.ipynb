# %% [markdown]
# # Stress test, kappa only

# %%
import sys
import pandas as pd
import numpy as np
import random
import tensorflow as tf
import plotly.express as px
import plotly.graph_objects as go
import os
os.environ["PYTHONHASHSEED"] = "42"
os.environ["TF_DETERMINISTIC_OPS"] = "1"
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from pathlib import Path

project_root = Path.cwd()
while project_root != project_root.parent and not (project_root / "src").exists():
    project_root = project_root.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.simulation.dgp0 import Tier0Config, simulate_panel
from src.simulation.validation import plot_market_plotly, separation_auc_like
from src.data.feature_eng import feature_eng_syn
from src.model.autoencoder import PriceAutoencoder


#set seed
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
df_kappa = pd.read_parquet("../data/processed_syn/synth_dgp0_kappa_only_L18.parquet")
df_kappa.head()
# Out:
#    market_id  window_start  window_end  window_length   Price 1   Price 2  \
# 0          0             0          17             18  0.089382  0.088709
# 1          0             1          18             18  0.088709  0.081665
# 2          0             2          19             18  0.081665  0.071810
# 3          0             3          20             18  0.071810  0.076316
# 4          0             4          21             18  0.076316  0.076378
#
#     Price 3   Price 4   Price 5   Price 6  ...  Price 14  Price 15  Price 16  \
# 0  0.081665  0.071810  0.076316  0.076378  ...  0.011050 -0.002371 -0.012381
# 1  0.071810  0.076316  0.076378  0.079745  ... -0.002371 -0.012381 -0.024323
# 2  0.076316  0.076378  0.079745  0.052573  ... -0.012381 -0.024323 -0.020946
# 3  0.076378  0.079745  0.052573  0.078968  ... -0.024323 -0.020946 -0.078320
# 4  0.079745  0.052573  0.078968  0.089319  ... -0.020946 -0.078320 -0.095198
#
#    Price 17  Price 18   share_C   share_T  share_K  state_mode  is_pure_80
# 0 -0.024323 -0.020946  0.111111  0.888889      0.0           1         1.0
# 1 -0.020946 -0.078320  0.166667  0.833333      0.0           1         1.0
# 2 -0.078320 -0.095198  0.222222  0.777778      0.0           1         0.0
# 3 -0.095198 -0.105134  0.277778  0.722222      0.0           1         0.0
# 4 -0.105134 -0.100654  0.333333  0.666667      0.0           1         0.0
#
# [5 rows x 27 columns]

# %%
feature_df = feature_eng_syn(df_kappa)
feature_df.head()
# Out:
#    market_id  window_start  window_end  window_length   Price 1   Price 2  \
# 0          0             0          17             18  0.089382  0.088709
# 1          0             1          18             18  0.088709  0.081665
# 2          0             2          19             18  0.081665  0.071810
# 3          0             3          20             18  0.071810  0.076316
# 4          0             4          21             18  0.076316  0.076378
#
#     Price 3   Price 4   Price 5   Price 6  ...  CoV_change  \
# 0  0.081665  0.071810  0.076316  0.076378  ...    2.276474
# 1  0.071810  0.076316  0.076378  0.079745  ...    1.924273
# 2  0.076316  0.076378  0.079745  0.052573  ...    1.822711
# 3  0.076378  0.079745  0.052573  0.078968  ...    1.821877
# 4  0.079745  0.052573  0.078968  0.089319  ...    1.821487
#
#    zero_change_fraction      AR_1      AR_2  kurtosis_change  max_abs_ret  \
# 0              0.117647 -0.015490  0.053722         1.737080     0.042639
# 1              0.058824 -0.121106  0.094237         1.619953     0.057374
# 2              0.058824 -0.040472  0.079848         1.444830     0.057374
# 3              0.058824 -0.043120  0.050544         1.444103     0.057374
# 4              0.058824 -0.070229 -0.006613         1.444913     0.057374
#
#     pos_vol   neg_vol  level_vol  price_range
# 0  0.009612  0.011403   0.041615     0.113704
# 1  0.009612  0.016329   0.050188     0.167639
# 2  0.009612  0.015838   0.057970     0.184517
# 3  0.009612  0.015833   0.064619     0.194453
# 4  0.009614  0.015833   0.069139     0.194453
#
# [5 rows x 39 columns]

# %%
FEATURES_5 = [
    "volatility", "zero_change_fraction","max_abs_ret",
    "AR_1","price_range"]

pure_kappa = feature_df[feature_df["is_pure_80"] == 1]

pure_kappa.groupby("state_mode")[FEATURES_5].mean()
# Out:
#             volatility  zero_change_fraction  max_abs_ret      AR_1  \
# state_mode
# 0             0.034483              0.028019     0.079287  0.070697
# 1             0.025519              0.034179     0.058372  0.151225
# 2             0.018176              0.052667     0.040757  0.162817
#
#             price_range
# state_mode
# 0              0.182906
# 1              0.150671
# 2              0.116705

# %% [markdown]
# ## Training AE

# %%
X = feature_df[FEATURES_5].to_numpy().astype(np.float32)

# Scale
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X).astype(np.float32)

#train test split
X_train, X_val = train_test_split(X_scaled, test_size=0.2, random_state=42)

# %%
ae = PriceAutoencoder(input_dim=5, latent_dim=2, hidden_dims=(16,8), latent_activation=None)
ae.compile(optimizer=tf.keras.optimizers.Adam(1e-3), loss="mse")

history = ae.fit(
    X_train, X_train,
    validation_data=(X_val, X_val),
    epochs=200,
    batch_size=256,
    callbacks=[tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)],
    verbose=1
)
# Out:
# Epoch 1/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8302 - val_loss: 0.5640
# Epoch 2/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3006 - val_loss: 0.2036
# Epoch 3/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1829 - val_loss: 0.1661
# Epoch 4/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1580 - val_loss: 0.1514
# Epoch 5/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1468 - val_loss: 0.1441
# Epoch 6/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1404 - val_loss: 0.1396
# Epoch 7/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1363 - val_loss: 0.1364
# Epoch 8/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1330 - val_loss: 0.1333
# Epoch 9/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1299 - val_loss: 0.1308
# Epoch 10/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1278 - val_loss: 0.1291
# Epoch 11/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1262 - val_loss: 0.1277
# Epoch 12/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1249 - val_loss: 0.1265
# Epoch 13/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1236 - val_loss: 0.1252
# Epoch 14/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1224 - val_loss: 0.1240
# Epoch 15/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1213 - val_loss: 0.1230
# Epoch 16/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1203 - val_loss: 0.1222
# Epoch 17/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1195 - val_loss: 0.1215
# Epoch 18/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1188 - val_loss: 0.1208
# Epoch 19/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1181 - val_loss: 0.1202
# Epoch 20/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1176 - val_loss: 0.1197
# Epoch 21/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1170 - val_loss: 0.1193
# Epoch 22/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1165 - val_loss: 0.1188
# Epoch 23/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1160 - val_loss: 0.1183
# Epoch 24/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1155 - val_loss: 0.1177
# Epoch 25/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1149 - val_loss: 0.1172
# Epoch 26/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1144 - val_loss: 0.1167
# Epoch 27/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1139 - val_loss: 0.1163
# Epoch 28/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1134 - val_loss: 0.1159
# Epoch 29/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1130 - val_loss: 0.1154
# Epoch 30/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1126 - val_loss: 0.1150
# Epoch 31/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1122 - val_loss: 0.1147
# Epoch 32/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1118 - val_loss: 0.1145
# Epoch 33/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1115 - val_loss: 0.1142
# Epoch 34/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1113 - val_loss: 0.1139
# Epoch 35/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1110 - val_loss: 0.1137
# Epoch 36/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1108 - val_loss: 0.1135
# Epoch 37/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1106 - val_loss: 0.1134
# Epoch 38/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1103 - val_loss: 0.1132
# Epoch 39/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1101 - val_loss: 0.1130
# Epoch 40/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1099 - val_loss: 0.1128
# Epoch 41/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1097 - val_loss: 0.1126
# Epoch 42/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1095 - val_loss: 0.1125
# Epoch 43/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1093 - val_loss: 0.1122
# Epoch 44/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1091 - val_loss: 0.1121
# Epoch 45/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1090 - val_loss: 0.1119
# Epoch 46/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1088 - val_loss: 0.1118
# Epoch 47/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1086 - val_loss: 0.1116
# Epoch 48/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1084 - val_loss: 0.1114
# Epoch 49/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1083 - val_loss: 0.1113
# Epoch 50/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1081 - val_loss: 0.1111
# Epoch 51/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1079 - val_loss: 0.1109
# Epoch 52/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1078 - val_loss: 0.1108
# Epoch 53/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1076 - val_loss: 0.1107
# Epoch 54/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1075 - val_loss: 0.1105
# Epoch 55/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1074 - val_loss: 0.1104
# Epoch 56/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1072 - val_loss: 0.1103
# Epoch 57/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1071 - val_loss: 0.1101
# Epoch 58/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1069 - val_loss: 0.1100
# Epoch 59/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1068 - val_loss: 0.1099
# Epoch 60/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1067 - val_loss: 0.1098
# Epoch 61/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1065 - val_loss: 0.1096
# Epoch 62/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1064 - val_loss: 0.1095
# Epoch 63/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1063 - val_loss: 0.1094
# Epoch 64/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1062 - val_loss: 0.1093
# Epoch 65/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1061 - val_loss: 0.1092
# Epoch 66/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1060 - val_loss: 0.1091
# Epoch 67/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1059 - val_loss: 0.1090
# Epoch 68/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1058 - val_loss: 0.1089
# Epoch 69/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1057 - val_loss: 0.1088
# Epoch 70/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1056 - val_loss: 0.1087
# Epoch 71/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1055 - val_loss: 0.1087
# Epoch 72/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1054 - val_loss: 0.1085
# Epoch 73/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1053 - val_loss: 0.1085
# Epoch 74/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1052 - val_loss: 0.1084
# Epoch 75/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1051 - val_loss: 0.1083
# Epoch 76/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1051 - val_loss: 0.1082
# Epoch 77/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1050 - val_loss: 0.1082
# Epoch 78/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1049 - val_loss: 0.1081
# Epoch 79/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1048 - val_loss: 0.1080
# Epoch 80/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1047 - val_loss: 0.1079
# Epoch 81/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1047 - val_loss: 0.1079
# Epoch 82/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1046 - val_loss: 0.1078
# Epoch 83/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1045 - val_loss: 0.1078
# Epoch 84/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1045 - val_loss: 0.1077
# Epoch 85/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1044 - val_loss: 0.1076
# Epoch 86/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1043 - val_loss: 0.1076
# Epoch 87/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1043 - val_loss: 0.1076
# Epoch 88/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1042 - val_loss: 0.1075
# Epoch 89/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1042 - val_loss: 0.1074
# Epoch 90/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1041 - val_loss: 0.1074
# Epoch 91/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1041 - val_loss: 0.1073
# Epoch 92/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1040 - val_loss: 0.1073
# Epoch 93/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1040 - val_loss: 0.1072
# Epoch 94/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1039 - val_loss: 0.1071
# Epoch 95/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1038 - val_loss: 0.1070
# Epoch 96/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1037 - val_loss: 0.1070
# Epoch 97/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1037 - val_loss: 0.1070
# Epoch 98/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1036 - val_loss: 0.1069
# Epoch 99/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1036 - val_loss: 0.1068
# Epoch 100/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1035 - val_loss: 0.1067
# Epoch 101/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1035 - val_loss: 0.1068
# Epoch 102/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1034 - val_loss: 0.1066
# Epoch 103/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1033 - val_loss: 0.1065
# Epoch 104/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1032 - val_loss: 0.1064
# Epoch 105/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1032 - val_loss: 0.1064
# Epoch 106/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1031 - val_loss: 0.1063
# Epoch 107/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1030 - val_loss: 0.1064
# Epoch 108/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1029 - val_loss: 0.1061
# Epoch 109/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1029 - val_loss: 0.1062
# Epoch 110/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1028 - val_loss: 0.1061
# Epoch 111/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1027 - val_loss: 0.1059
# Epoch 112/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1026 - val_loss: 0.1058
# Epoch 113/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1025 - val_loss: 0.1057
# Epoch 114/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1025 - val_loss: 0.1056
# Epoch 115/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1024 - val_loss: 0.1055
# Epoch 116/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1024 - val_loss: 0.1053
# Epoch 117/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1023 - val_loss: 0.1053
# Epoch 118/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1022 - val_loss: 0.1052
# Epoch 119/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1021 - val_loss: 0.1050
# Epoch 120/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1020 - val_loss: 0.1051
# Epoch 121/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1019 - val_loss: 0.1050
# Epoch 122/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1019 - val_loss: 0.1047
# Epoch 123/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1018 - val_loss: 0.1047
# Epoch 124/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1017 - val_loss: 0.1047
# Epoch 125/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1016 - val_loss: 0.1044
# Epoch 126/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1015 - val_loss: 0.1044
# Epoch 127/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1014 - val_loss: 0.1044
# Epoch 128/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1013 - val_loss: 0.1042
# Epoch 129/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1012 - val_loss: 0.1041
# Epoch 130/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1012 - val_loss: 0.1040
# Epoch 131/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1011 - val_loss: 0.1039
# Epoch 132/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1010 - val_loss: 0.1038
# Epoch 133/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1009 - val_loss: 0.1038
# Epoch 134/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1008 - val_loss: 0.1037
# Epoch 135/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - loss: 0.1007 - val_loss: 0.1036
# Epoch 136/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1006 - val_loss: 0.1035
# Epoch 137/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1006 - val_loss: 0.1034
# Epoch 138/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1004 - val_loss: 0.1032
# Epoch 139/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - loss: 0.1004 - val_loss: 0.1032
# Epoch 140/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1003 - val_loss: 0.1031
# Epoch 141/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1001 - val_loss: 0.1030
# Epoch 142/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1000 - val_loss: 0.1028
# Epoch 143/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - loss: 0.0999 - val_loss: 0.1026
# Epoch 144/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0998 - val_loss: 0.1026
# Epoch 145/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0996 - val_loss: 0.1023
# Epoch 146/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - loss: 0.0995 - val_loss: 0.1021
# Epoch 147/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0994 - val_loss: 0.1021
# Epoch 148/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0991 - val_loss: 0.1018
# Epoch 149/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0991 - val_loss: 0.1017
# Epoch 150/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0989 - val_loss: 0.1011
# Epoch 151/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0989 - val_loss: 0.1011
# Epoch 152/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0986 - val_loss: 0.1011
# Epoch 153/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0982 - val_loss: 0.1009
# Epoch 154/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0981 - val_loss: 0.1007
# Epoch 155/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0981 - val_loss: 0.1008
# Epoch 156/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 0.0978 - val_loss: 0.1005
# Epoch 157/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0975 - val_loss: 0.1002
# Epoch 158/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 0.0973 - val_loss: 0.1001
# Epoch 159/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0972 - val_loss: 0.1000
# Epoch 160/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - loss: 0.0970 - val_loss: 0.0995
# Epoch 161/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0972 - val_loss: 0.0996
# Epoch 162/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0967 - val_loss: 0.0994
# Epoch 163/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - loss: 0.0965 - val_loss: 0.0990
# Epoch 164/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0962 - val_loss: 0.0989
# Epoch 165/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0960 - val_loss: 0.0983
# Epoch 166/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0960 - val_loss: 0.0984
# Epoch 167/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0957 - val_loss: 0.0983
# Epoch 168/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - loss: 0.0955 - val_loss: 0.0982
# Epoch 169/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0953 - val_loss: 0.0981
# Epoch 170/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0952 - val_loss: 0.0978
# Epoch 171/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0950 - val_loss: 0.0976
# Epoch 172/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0948 - val_loss: 0.0975
# Epoch 173/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0948 - val_loss: 0.0976
# Epoch 174/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0947 - val_loss: 0.0974
# Epoch 175/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0945 - val_loss: 0.0972
# Epoch 176/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0944 - val_loss: 0.0970
# Epoch 177/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0944 - val_loss: 0.0971
# Epoch 178/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0942 - val_loss: 0.0968
# Epoch 179/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0940 - val_loss: 0.0968
# Epoch 180/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0939 - val_loss: 0.0967
# Epoch 181/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0937 - val_loss: 0.0964
# Epoch 182/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - loss: 0.0935 - val_loss: 0.0964
# Epoch 183/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0934 - val_loss: 0.0962
# Epoch 184/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0933 - val_loss: 0.0962
# Epoch 185/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0932 - val_loss: 0.0959
# Epoch 186/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0932 - val_loss: 0.0954
# Epoch 187/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0931 - val_loss: 0.0959
# Epoch 188/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0928 - val_loss: 0.0958
# Epoch 189/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 0.0928 - val_loss: 0.0956
# Epoch 190/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0928 - val_loss: 0.0955
# Epoch 191/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0927 - val_loss: 0.0952
# Epoch 192/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0925 - val_loss: 0.0950
# Epoch 193/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0923 - val_loss: 0.0948
# Epoch 194/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0924 - val_loss: 0.0949
# Epoch 195/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0923 - val_loss: 0.0948
# Epoch 196/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0921 - val_loss: 0.0947
# Epoch 197/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0921 - val_loss: 0.0945
# Epoch 198/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0920 - val_loss: 0.0944
# Epoch 199/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0918 - val_loss: 0.0944
# Epoch 200/200
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0917 - val_loss: 0.0943

# %% [markdown]
# ## Checking Embedding

# %%
Z = ae.encoder(X_scaled).numpy()

validation_df = feature_df.copy()

validation_df["z1"] = Z[:, 0]
validation_df["z2"] = Z[:, 1]

# %%
#plotting embedding
# Focus on pure windows only for clarity
pure = validation_df[validation_df["is_pure_80"] == 1].copy()

# Map state labels for readability
state_map = {0: "Competitive", 1: "Tacit", 2: "Cartel"}
pure["state_label"] = pure["state_mode"].map(state_map)

fig = px.scatter(
    pure,
    x="z1",
    y="z2",
    color="state_label",
    color_discrete_map={
        "Competitive": "green",
        "Tacit": "orange",
        "Cartel": "red",
    },
    title="Latent Space (Pure Windows Only) Kappa Only",
    opacity=0.6
)

fig.update_layout(template="plotly_white")
fig.show()

# %% [markdown]
# ## Calculating centroids

# %%
Z_pure = pure[["z1","z2"]].to_numpy()


#cacluating centroids
mu_C = pure[pure["state_mode"] == 0][["z1","z2"]].mean().to_numpy()
mu_K = pure[pure["state_mode"] == 2][["z1","z2"]].mean().to_numpy()
mu_T = pure[pure["state_mode"] == 1][["z1","z2"]].mean().to_numpy()

#calculating competition direction and scalling 
v = mu_K - mu_C
v = v / np.linalg.norm(v)

# %%
#projecting each coordinate on competitoin axis
Z_all = validation_df[["z1","z2"]].to_numpy()
validation_df["conduct_score"] = Z_all @ v
validation_df["conduct_score_centred"] = (Z_all - mu_C) @ v

# %%
validation_df.groupby("state_mode")["conduct_score"].mean()
# Out:
# state_mode
# 0   -0.123068
# 1    0.450820
# 2    1.382638
# Name: conduct_score, dtype: float32

# %%
validation_df.groupby("state_mode")["conduct_score"].describe()
# Out:
#               count      mean       std       min       25%       50%  \
# state_mode
# 0            9572.0 -0.123068  1.655169 -4.815728 -0.993650 -0.328058
# 1            9494.0  0.450820  1.956770 -3.907100 -0.416771  0.051065
# 2           13534.0  1.382638  2.501534 -3.695632 -0.052977  0.388965
#
#                  75%        max
# state_mode
# 0           0.191251  13.707209
# 1           0.835331  14.949136
# 2           1.416593  17.638617

# %% [markdown]
# ## Understanding classification

# %%
state_map = {0: "Competitive", 1: "Tacit", 2: "Cartel"}

pure["state_label"] = pure["state_mode"].map(state_map)
validation_df["state_label"] = validation_df["state_mode"].map(state_map)

# %%
fig = px.scatter(
    pure,
    x="z1",
    y="z2",
    color="state_label",
    opacity=0,
    title="Latent Space (Kappa only) with Centroids and Conduct Axis",
    template="plotly_white"
)

# Add centroid markers
centroids = np.vstack([mu_C, mu_T, mu_K])
centroid_labels = ["Competitive centroid", "Tacit centroid", "Cartel centroid"]

fig.add_trace(go.Scatter(
    x=centroids[:,0],
    y=centroids[:,1],
    mode="markers+text",
    text=centroid_labels,
    textposition="top center",
    marker=dict(size=14, symbol="x"),
    name="Centroids"
))

# Add arrow from mu_C to mu_K
fig.add_trace(go.Scatter(
    x=[mu_C[0], mu_K[0]],
    y=[mu_C[1], mu_K[1]],
    mode="lines",
    line=dict(width=4, dash="dash"),
    name="Conduct axis (C → K)"
))

# Optional: annotate arrow direction
fig.add_annotation(
    x=mu_K[0], y=mu_K[1],
    ax=mu_C[0], ay=mu_C[1],
    xref="x", yref="y", axref="x", ayref="y",
    showarrow=True, arrowhead=3, arrowsize=1.2, arrowwidth=2,
    text="C→K"
)

fig.show()

# %%
fig = px.histogram(
    validation_df,
    x="conduct_score_centred",
    color="state_label",
    nbins=60,
    opacity=0.5,
    barmode="overlay",
    title="Centered Conduct Score Distribution by Regime (All Windows) kappa only",
    template="plotly_white"
)
fig.show()

# %% [markdown]
# ### Probabilty of getting classification correct

# %%
scores_C = validation_df[validation_df["state_mode"] == 0]["conduct_score_centred"].values
scores_K = validation_df[validation_df["state_mode"] == 2]["conduct_score_centred"].values

sep = separation_auc_like(scores_C, scores_K)
print(sep)
# Out:
# 0.7526
